# %%
#this line tells to plot the matplotlib graphs inline!

# %matplotlib inline

import requests
import bs4
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams

def make_simple_plot():
    fig, axes=plt.subplots(figsize=(12,5), nrows=1, ncols=2);
    axes[0].set_ylabel("$y$")
    axes[0].set_xlabel("$x$")
    axes[1].set_xlabel("$x$")
    axes[1].set_yticklabels([])
    axes[0].set_ylim([-2,2])
    axes[1].set_ylim([-2,2])
    plt.tight_layout();
    return axes

rcParams['figure.figsize'] = (20, 10)
rcParams['figure.dpi'] = 150
#rcParams['axes.prop_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.grid'] = True
rcParams['axes.facecolor'] = '#eeeeee'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'none'

# %%
req = requests.get("https://www.fbi.gov/about-us/cjis/ucr/crime-in-the-u.s/2013/crime-in-the-u.s.-2013/tables/1tabledatadecoverviewpdf/table_1_crime_in_the_united_states_by_volume_and_rate_per_100000_inhabitants_1994-2013.xls").text

# %%
soup = bs4.BeautifulSoup(req, "html.parser")

# %%
table = soup.find("table", "data")
tr = table.find("thead").find("tr")
#extract the column names from the table 
columns = [attr.text for attr in tr.find_all("th")]
#remove the /n from the column names
cleaned_columns = [re.sub('\n', "", col) for col in columns]
cleaned_columns = [re.sub('[1-9]', "", col) for col in cleaned_columns]
cleaned_columns
# Out:
# ['Year',
#  'Population',
#  'Violentcrime',
#  'Violent crime rate ',
#  'Murder andnonnegligent manslaughter',
#  'Murder and nonnegligent manslaughter rate ',
#  'Rape(legacydefinition)',
#  'Rape(legacydefinition)rate',
#  'Robbery',
#  'Robbery rate ',
#  'Aggravated assault',
#  'Aggravated assault rate ',
#  'Property crime',
#  'Property crime rate ',
#  'Burglary',
#  'Burglary rate ',
#  'Larceny-theft',
#  'Larceny-theft rate ',
#  'Motor vehicle theft',
#  'Motor vehicle theft rate ']

# %%
#get all the data rows
data_rows = table.find("tbody").find_all("tr")
data_rows = data_rows[:19]
list_data = []
years = []
for row in data_rows:
    data_in_row = row.find_all("td")
    years.append((row.find("th")).text)
    act_data = [data.text for data in data_in_row]
    list_data.append(act_data)
#coolest list comprehention written!!, cleaned the data
cleaned_data = [[re.sub('\n', "", th) for th in rows] for rows in list_data] 
#also remove all the commas
cleaned_data = [[re.sub(',', "", th) for th in rows] for rows in cleaned_data]    
#the only task left is to append year in the starting of list in every data
cleaned_data[:1]
# Out:
# [['260327021',
#   '1857670',
#   '713.6',
#   '23326',
#   '9.0',
#   '102216',
#   '39.3',
#   '618949',
#   '237.8',
#   '1113179',
#   '427.6',
#   '12131873',
#   '4660.2',
#   '2712774',
#   '1042.1',
#   '7879812',
#   '3026.9',
#   '1539287',
#   '591.3']]

# %%
#But first we have to clean the data and remove idiot datapoints 
#remove /n
years = [re.sub('\n', "", y) for y in years]
years = [y[:4] for y in years]
#cleaned_data[0].insert(0, years[0])
for i in range(19):
    cleaned_data[i].insert(0, years[i])
#this is the final data    
cleaned_data[:1]
# Out:
# [['1994',
#   '260327021',
#   '1857670',
#   '713.6',
#   '23326',
#   '9.0',
#   '102216',
#   '39.3',
#   '618949',
#   '237.8',
#   '1113179',
#   '427.6',
#   '12131873',
#   '4660.2',
#   '2712774',
#   '1042.1',
#   '7879812',
#   '3026.9',
#   '1539287',
#   '591.3']]

# %%
cleaned_data = np.asarray(cleaned_data)
data_org = pd.DataFrame(cleaned_data, columns = cleaned_columns)

# %% [markdown]
# ## HELL YEAH!!

# %%
data_org.head()
# Out:
#    Year Population Violentcrime Violent crime rate   \
# 0  1994  260327021      1857670               713.6
# 1  1995  262803276      1798792               684.5
# 2  1996  265228572      1688540               636.6
# 3  1997  267783607      1636096               611.0
# 4  1998  270248003      1533887               567.6
#
#   Murder andnonnegligent manslaughter  \
# 0                               23326
# 1                               21606
# 2                               19645
# 3                               18208
# 4                               16974
#
#   Murder and nonnegligent manslaughter rate  Rape(legacydefinition)  \
# 0                                        9.0                 102216
# 1                                        8.2                  97470
# 2                                        7.4                  96252
# 3                                        6.8                  96153
# 4                                        6.3                  93144
#
#   Rape(legacydefinition)rate Robbery Robbery rate  Aggravated assault  \
# 0                       39.3  618949         237.8            1113179
# 1                       37.1  580509         220.9            1099207
# 2                       36.3  535594         201.9            1037049
# 3                       35.9  498534         186.2            1023201
# 4                       34.5  447186         165.5             976583
#
#   Aggravated assault rate  Property crime Property crime rate  Burglary  \
# 0                    427.6       12131873               4660.2  2712774
# 1                    418.3       12063935               4590.5  2593784
# 2                    391.0       11805323               4451.0  2506400
# 3                    382.1       11558475               4316.3  2460526
# 4                    361.4       10951827               4052.5  2332735
#
#   Burglary rate  Larceny-theft Larceny-theft rate  Motor vehicle theft  \
# 0         1042.1       7879812              3026.9             1539287
# 1          987.0       7997710              3043.2             1472441
# 2          945.0       7904685              2980.3             1394238
# 3          918.8       7743760              2891.8             1354189
# 4          863.2       7376311              2729.5             1242781
#
#   Motor vehicle theft rate
# 0                     591.3
# 1                     560.3
# 2                     525.7
# 3                     505.7
# 4                     459.9

# %%
data_org.dtypes
# Out:
# Year                                          object
# Population                                    object
# Violentcrime                                  object
# Violent crime rate                            object
# Murder andnonnegligent manslaughter           object
# Murder and nonnegligent manslaughter rate     object
# Rape(legacydefinition)                        object
# Rape(legacydefinition)rate                    object
# Robbery                                       object
# Robbery rate                                  object
# Aggravated assault                            object
# Aggravated assault rate                       object
# Property crime                                object
# Property crime rate                           object
# Burglary                                      object
# Burglary rate                                 object
# Larceny-theft                                 object
# Larceny-theft rate                            object
# Motor vehicle theft                           object
# Motor vehicle theft rate                      object
# dtype: object

# %%
#convert the data types of the data accordingly 
#if the data is rate, convert it to float
#else convert it to integer
for col in cleaned_columns:
    if 'rate' in col:
        data_org[col] = data_org[col].astype(float)
    else:    
        data_org[col] = data_org[col].astype(int)
data_org.dtypes
# Out:
# Year                                            int64
# Population                                      int64
# Violentcrime                                    int64
# Violent crime rate                            float64
# Murder andnonnegligent manslaughter             int64
# Murder and nonnegligent manslaughter rate     float64
# Rape(legacydefinition)                          int64
# Rape(legacydefinition)rate                    float64
# Robbery                                         int64
# Robbery rate                                  float64
# Aggravated assault                              int64
# Aggravated assault rate                       float64
# Property crime                                  int64
# Property crime rate                           float64
# Burglary                                        int64
# Burglary rate                                 float64
# Larceny-theft                                   int64
# Larceny-theft rate                            float64
# Motor vehicle theft                             int64
# Motor vehicle theft rate                      float64
# dtype: object

# %%
data_org.head()
# Out:
#    Year  Population  Violentcrime  Violent crime rate   \
# 0  1994   260327021       1857670                713.6
# 1  1995   262803276       1798792                684.5
# 2  1996   265228572       1688540                636.6
# 3  1997   267783607       1636096                611.0
# 4  1998   270248003       1533887                567.6
#
#    Murder andnonnegligent manslaughter  \
# 0                                23326
# 1                                21606
# 2                                19645
# 3                                18208
# 4                                16974
#
#    Murder and nonnegligent manslaughter rate   Rape(legacydefinition)  \
# 0                                         9.0                  102216
# 1                                         8.2                   97470
# 2                                         7.4                   96252
# 3                                         6.8                   96153
# 4                                         6.3                   93144
#
#    Rape(legacydefinition)rate  Robbery  Robbery rate   Aggravated assault  \
# 0                        39.3   618949          237.8             1113179
# 1                        37.1   580509          220.9             1099207
# 2                        36.3   535594          201.9             1037049
# 3                        35.9   498534          186.2             1023201
# 4                        34.5   447186          165.5              976583
#
#    Aggravated assault rate   Property crime  Property crime rate   Burglary  \
# 0                     427.6        12131873                4660.2   2712774
# 1                     418.3        12063935                4590.5   2593784
# 2                     391.0        11805323                4451.0   2506400
# 3                     382.1        11558475                4316.3   2460526
# 4                     361.4        10951827                4052.5   2332735
#
#    Burglary rate   Larceny-theft  Larceny-theft rate   Motor vehicle theft  \
# 0          1042.1        7879812               3026.9              1539287
# 1           987.0        7997710               3043.2              1472441
# 2           945.0        7904685               2980.3              1394238
# 3           918.8        7743760               2891.8              1354189
# 4           863.2        7376311               2729.5              1242781
#
#    Motor vehicle theft rate
# 0                      591.3
# 1                      560.3
# 2                      525.7
# 3                      505.7
# 4                      459.9

# %% [markdown]
# ### Now as the data has been cleaned, we can explore the data using different plots!

# %%
data_org.corr()
# Out:
#                                                 Year  Population  \
# Year                                        1.000000    0.993508
# Population                                  0.993508    1.000000
# Violentcrime                               -0.897316   -0.897425
# Violent crime rate                         -0.938832   -0.944430
# Murder andnonnegligent manslaughter        -0.743743   -0.741423
# Murder and nonnegligent manslaughter rate  -0.850785   -0.854499
# Rape(legacydefinition)                     -0.775340   -0.736677
# Rape(legacydefinition)rate                 -0.956904   -0.946504
# Robbery                                    -0.789395   -0.789106
# Robbery rate                               -0.868983   -0.873522
# Aggravated assault                         -0.947561   -0.949665
# Aggravated assault rate                    -0.964617   -0.971718
# Property crime                             -0.946038   -0.938416
# Property crime rate                        -0.971410   -0.973061
# Burglary                                   -0.658926   -0.688005
# Burglary rate                              -0.854943   -0.877720
# Larceny-theft                              -0.963450   -0.957702
# Larceny-theft rate                         -0.979712   -0.982808
# Motor vehicle theft                        -0.906252   -0.868763
# Motor vehicle theft rate                   -0.953103   -0.928543
#
#                                             Violentcrime  Violent crime rate   \
# Year                                           -0.897316            -0.938832
# Population                                     -0.897425            -0.944430
# Violentcrime                                    1.000000             0.991019
# Violent crime rate                              0.991019             1.000000
# Murder andnonnegligent manslaughter             0.948187             0.913199
# Murder and nonnegligent manslaughter rate       0.982452             0.971506
# Rape(legacydefinition)                          0.857273             0.825885
# Rape(legacydefinition)rate                      0.955825             0.967998
# Robbery                                         0.976989             0.944407
# Robbery rate                                    0.995333             0.983953
# Aggravated assault                              0.988144             0.996917
# Aggravated assault rate                         0.973017             0.994232
# Property crime                                  0.964221             0.974028
# Property crime rate                             0.959926             0.983693
# Burglary                                        0.884657             0.862313
# Burglary rate                                   0.962393             0.968811
# Larceny-theft                                   0.940316             0.962093
# Larceny-theft rate                              0.940926             0.972517
# Motor vehicle theft                             0.865277             0.868203
# Motor vehicle theft rate                        0.913712             0.926375
#
#                                             Murder andnonnegligent manslaughter  \
# Year                                                                  -0.743743
# Population                                                            -0.741423
# Violentcrime                                                           0.948187
# Violent crime rate                                                     0.913199
# Murder andnonnegligent manslaughter                                    1.000000
# Murder and nonnegligent manslaughter rate                              0.980518
# Rape(legacydefinition)                                                 0.853855
# Rape(legacydefinition)rate                                             0.871612
# Robbery                                                                0.982235
# Robbery rate                                                           0.965259
# Aggravated assault                                                     0.895321
# Aggravated assault rate                                                0.866866
# Property crime                                                         0.882871
# Property crime rate                                                    0.856284
# Burglary                                                               0.924068
# Burglary rate                                                          0.923881
# Larceny-theft                                                          0.828354
# Larceny-theft rate                                                     0.817305
# Motor vehicle theft                                                    0.785579
# Motor vehicle theft rate                                               0.822284
#
#                                             Murder and nonnegligent manslaughter rate   \
# Year                                                                         -0.850785
# Population                                                                   -0.854499
# Violentcrime                                                                  0.982452
# Violent crime rate                                                            0.971506
# Murder andnonnegligent manslaughter                                           0.980518
# Murder and nonnegligent manslaughter rate                                     1.000000
# Rape(legacydefinition)                                                        0.849425
# Rape(legacydefinition)rate                                                    0.933858
# Robbery                                                                       0.978491
# Robbery rate                                                                  0.991797
# Aggravated assault                                                            0.956859
# Aggravated assault rate                                                       0.943706
# Property crime                                                                0.940732
# Property crime rate                                                           0.933997
# Burglary                                                                      0.919255
# Burglary rate                                                                 0.969296
# Larceny-theft                                                                 0.904512
# Larceny-theft rate                                                            0.906932
# Motor vehicle theft                                                           0.833375
# Motor vehicle theft rate                                                      0.884380
#
#                                             Rape(legacydefinition)  \
# Year                                                     -0.775340
# Population                                               -0.736677
# Violentcrime                                              0.857273
# Violent crime rate                                        0.825885
# Murder andnonnegligent manslaughter                       0.853855
# Murder and nonnegligent manslaughter rate                 0.849425
# Rape(legacydefinition)                                    1.000000
# Rape(legacydefinition)rate                                0.911494
# Robbery                                                   0.848641
# Robbery rate                                              0.840698
# Aggravated assault                                        0.827254
# Aggravated assault rate                                   0.796792
# Property crime                                            0.881341
# Property crime rate                                       0.828860
# Burglary                                                  0.698879
# Burglary rate                                             0.766657
# Larceny-theft                                             0.835403
# Larceny-theft rate                                        0.795690
# Motor vehicle theft                                       0.929214
# Motor vehicle theft rate                                  0.909245
#
#                                             Rape(legacydefinition)rate  \
# Year                                                         -0.956904
# Population                                                   -0.946504
# Violentcrime                                                  0.955825
# Violent crime rate                                            0.967998
# Murder andnonnegligent manslaughter                           0.871612
# Murder and nonnegligent manslaughter rate                     0.933858
# Rape(legacydefinition)                                        0.911494
# Rape(legacydefinition)rate                                    1.000000
# Robbery                                                       0.893382
# Robbery rate                                                  0.938333
# Aggravated assault                                            0.968517
# Aggravated assault rate                                       0.967303
# Property crime                                                0.983375
# Property crime rate                                           0.980454
# Burglary                                                      0.778645
# Burglary rate                                                 0.912428
# Larceny-theft                                                 0.970254
# Larceny-theft rate                                            0.968585
# Motor vehicle theft                                           0.946998
# Motor vehicle theft rate                                      0.979277
#
#                                              Robbery  Robbery rate   \
# Year                                       -0.789395      -0.868983
# Population                                 -0.789106      -0.873522
# Violentcrime                                0.976989       0.995333
# Violent crime rate                          0.944407       0.983953
# Murder andnonnegligent manslaughter         0.982235       0.965259
# Murder and nonnegligent manslaughter rate   0.978491       0.991797
# Rape(legacydefinition)                      0.848641       0.840698
# Rape(legacydefinition)rate                  0.893382       0.938333
# Robbery                                     1.000000       0.986742
# Robbery rate                                0.986742       1.000000
# Aggravated assault                          0.933051       0.973964
# Aggravated assault rate                     0.904549       0.959330
# Property crime                              0.906509       0.948769
# Property crime rate                         0.886881       0.944837
# Burglary                                    0.922146       0.914236
# Burglary rate                               0.940687       0.972612
# Larceny-theft                               0.863288       0.919816
# Larceny-theft rate                          0.855362       0.922508
# Motor vehicle theft                         0.795990       0.831998
# Motor vehicle theft rate                    0.838609       0.885872
#
#                                             Aggravated assault  \
# Year                                                 -0.947561
# Population                                           -0.949665
# Violentcrime                                          0.988144
# Violent crime rate                                    0.996917
# Murder andnonnegligent manslaughter                   0.895321
# Murder and nonnegligent manslaughter rate             0.956859
# Rape(legacydefinition)                                0.827254
# Rape(legacydefinition)rate                            0.968517
# Robbery                                               0.933051
# Robbery rate                                          0.973964
# Aggravated assault                                    1.000000
# Aggravated assault rate                               0.995365
# Property crime                                        0.975041
# Property crime rate                                   0.983802
# Burglary                                              0.835907
# Burglary rate                                         0.952967
# Larceny-theft                                         0.966604
# Larceny-theft rate                                    0.974946
# Motor vehicle theft                                   0.880932
# Motor vehicle theft rate                              0.934825
#
#                                             Aggravated assault rate   \
# Year                                                       -0.964617
# Population                                                 -0.971718
# Violentcrime                                                0.973017
# Violent crime rate                                          0.994232
# Murder andnonnegligent manslaughter                         0.866866
# Murder and nonnegligent manslaughter rate                   0.943706
# Rape(legacydefinition)                                      0.796792
# Rape(legacydefinition)rate                                  0.967303
# Robbery                                                     0.904549
# Robbery rate                                                0.959330
# Aggravated assault                                          0.995365
# Aggravated assault rate                                     1.000000
# Property crime                                              0.971904
# Property crime rate                                         0.990602
# Burglary                                                    0.819715
# Burglary rate                                               0.952614
# Larceny-theft                                               0.970901
# Larceny-theft rate                                          0.986646
# Motor vehicle theft                                         0.870467
# Motor vehicle theft rate                                    0.931837
#
#                                             Property crime  \
# Year                                             -0.946038
# Population                                       -0.938416
# Violentcrime                                      0.964221
# Violent crime rate                                0.974028
# Murder andnonnegligent manslaughter               0.882871
# Murder and nonnegligent manslaughter rate         0.940732
# Rape(legacydefinition)                            0.881341
# Rape(legacydefinition)rate                        0.983375
# Robbery                                           0.906509
# Robbery rate                                      0.948769
# Aggravated assault                                0.975041
# Aggravated assault rate                           0.971904
# Property crime                                    1.000000
# Property crime rate                               0.990744
# Burglary                                          0.816386
# Burglary rate                                     0.933719
# Larceny-theft                                     0.992525
# Larceny-theft rate                                0.981677
# Motor vehicle theft                               0.930908
# Motor vehicle theft rate                          0.968030
#
#                                             Property crime rate   Burglary  \
# Year                                                   -0.971410 -0.658926
# Population                                             -0.973061 -0.688005
# Violentcrime                                            0.959926  0.884657
# Violent crime rate                                      0.983693  0.862313
# Murder andnonnegligent manslaughter                     0.856284  0.924068
# Murder and nonnegligent manslaughter rate               0.933997  0.919255
# Rape(legacydefinition)                                  0.828860  0.698879
# Rape(legacydefinition)rate                              0.980454  0.778645
# Robbery                                                 0.886881  0.922146
# Robbery rate                                            0.944837  0.914236
# Aggravated assault                                      0.983802  0.835907
# Aggravated assault rate                                 0.990602  0.819715
# Property crime                                          0.990744  0.816386
# Property crime rate                                     1.000000  0.805669
# Burglary                                                0.805669  1.000000
# Burglary rate                                           0.942964  0.951188
# Larceny-theft                                           0.991885  0.772489
# Larceny-theft rate                                      0.996942  0.773339
# Motor vehicle theft                                     0.904312  0.603447
# Motor vehicle theft rate                                0.956371  0.676914
#
#                                             Burglary rate   Larceny-theft  \
# Year                                             -0.854943      -0.963450
# Population                                       -0.877720      -0.957702
# Violentcrime                                      0.962393       0.940316
# Violent crime rate                                0.968811       0.962093
# Murder andnonnegligent manslaughter               0.923881       0.828354
# Murder and nonnegligent manslaughter rate         0.969296       0.904512
# Rape(legacydefinition)                            0.766657       0.835403
# Rape(legacydefinition)rate                        0.912428       0.970254
# Robbery                                           0.940687       0.863288
# Robbery rate                                      0.972612       0.919816
# Aggravated assault                                0.952967       0.966604
# Aggravated assault rate                           0.952614       0.970901
# Property crime                                    0.933719       0.992525
# Property crime rate                               0.942964       0.991885
# Burglary                                          0.951188       0.772489
# Burglary rate                                     1.000000       0.913348
# Larceny-theft                                     0.913348       1.000000
# Larceny-theft rate                                0.926012       0.992324
# Motor vehicle theft                               0.761485       0.916467
# Motor vehicle theft rate                          0.836996       0.959178
#
#                                             Larceny-theft rate   \
# Year                                                  -0.979712
# Population                                            -0.982808
# Violentcrime                                           0.940926
# Violent crime rate                                     0.972517
# Murder andnonnegligent manslaughter                    0.817305
# Murder and nonnegligent manslaughter rate              0.906932
# Rape(legacydefinition)                                 0.795690
# Rape(legacydefinition)rate                             0.968585
# Robbery                                                0.855362
# Robbery rate                                           0.922508
# Aggravated assault                                     0.974946
# Aggravated assault rate                                0.986646
# Property crime                                         0.981677
# Property crime rate                                    0.996942
# Burglary                                               0.773339
# Burglary rate                                          0.926012
# Larceny-theft                                          0.992324
# Larceny-theft rate                                     1.000000
# Motor vehicle theft                                    0.891851
# Motor vehicle theft rate                               0.947361
#
#                                             Motor vehicle theft  \
# Year                                                  -0.906252
# Population                                            -0.868763
# Violentcrime                                           0.865277
# Violent crime rate                                     0.868203
# Murder andnonnegligent manslaughter                    0.785579
# Murder and nonnegligent manslaughter rate              0.833375
# Rape(legacydefinition)                                 0.929214
# Rape(legacydefinition)rate                             0.946998
# Robbery                                                0.795990
# Robbery rate                                           0.831998
# Aggravated assault                                     0.880932
# Aggravated assault rate                                0.870467
# Property crime                                         0.930908
# Property crime rate                                    0.904312
# Burglary                                               0.603447
# Burglary rate                                          0.761485
# Larceny-theft                                          0.916467
# Larceny-theft rate                                     0.891851
# Motor vehicle theft                                    1.000000
# Motor vehicle theft rate                               0.988733
#
#                                             Motor vehicle theft rate
# Year                                                        -0.953103
# Population                                                  -0.928543
# Violentcrime                                                 0.913712
# Violent crime rate                                           0.926375
# Murder andnonnegligent manslaughter                          0.822284
# Murder and nonnegligent manslaughter rate                    0.884380
# Rape(legacydefinition)                                       0.909245
# Rape(legacydefinition)rate                                   0.979277
# Robbery                                                      0.838609
# Robbery rate                                                 0.885872
# Aggravated assault                                           0.934825
# Aggravated assault rate                                      0.931837
# Property crime                                               0.968030
# Property crime rate                                          0.956371
# Burglary                                                     0.676914
# Burglary rate                                                0.836996
# Larceny-theft                                                0.959178
# Larceny-theft rate                                           0.947361
# Motor vehicle theft                                          0.988733
# Motor vehicle theft rate                                     1.000000

# %%
rate_hist = {}
for col in cleaned_columns:
    if 'rate' in col:
        hig = col.upper()
        rate_hist[hig[:4]] = data_org[col].mean()

# %%
X = np.arange(len(rate_hist))
plt.bar(X, rate_hist.values(), align='center', width=0.5)
plt.xticks(X, rate_hist.keys())
plt.show()

# %% [markdown]
# This kind of shows us that Out of 100000 inhabitants, property thefs are at maximum in USA.

# %%
plt.plot(data_org['Population'], data_org['Violentcrime'], 'o-')

# %% [markdown]
# ### What we are seeing is a good thing, i.e. as the population is increasing the amount of crime is going down, though we see a slight increase near the end. Contrary to this, in India the crime is actually increasing with population.
